# %%
import pandas as pd

# %%
jan = "JC-202001-citibike-tripdata.csv"
feb = "JC-202002-citibike-tripdata.csv"
mar = "JC-202003-citibike-tripdata.csv"
apr = "JC-202004-citibike-tripdata.csv"
may = "JC-202005-citibike-tripdata.csv"
jun = "JC-202006-citibike-tripdata.csv"

# %%
Jan = pd.read_csv(jan)

# %%
Jan["starttime"][0]
# Out:
# '2020-01-01 00:04:50.1920'

# %%
Jan[['startdate', 'starttime']] = Jan.starttime.str.split(expand=True)

# %%
Jan[['stopdate', 'stoptime']] = Jan.stoptime.str.split(expand=True)

# %%
Jan = Jan[['tripduration','startdate','starttime','stopdate','stoptime','start station id','start station name','start station latitude','start station longitude','end station id','end station name','end station latitude','end station longitude','bikeid','usertype','birth year','gender']]

# %%
len(Jan)
# Out:
# 26020

# %%
Feb = pd.read_csv(feb)

# %%
Feb[['startdate', 'starttime']] = Feb.starttime.str.split(expand=True)

# %%
Feb[['stopdate', 'stoptime']] = Feb.stoptime.str.split(expand=True)

# %%
Feb = Feb[['tripduration','startdate','starttime','stopdate','stoptime','start station id','start station name','start station latitude','start station longitude','end station id','end station name','end station latitude','end station longitude','bikeid','usertype','birth year','gender']]

# %%
Feb.head()
# Out:
#    tripduration   startdate      starttime    stopdate       stoptime  \
# 0           841  2020-02-01  00:02:13.7650  2020-02-01  00:16:15.4720
# 1           206  2020-02-01  00:16:11.3850  2020-02-01  00:19:37.4460
# 2           859  2020-02-01  00:23:22.1090  2020-02-01  00:37:41.5060
# 3           693  2020-02-01  00:25:14.5170  2020-02-01  00:36:48.0280
# 4          1473  2020-02-01  00:32:30.5050  2020-02-01  00:57:04.3740
#
#    start station id  start station name  start station latitude  \
# 0              3199        Newport Pkwy               40.728745
# 1              3273        Manila & 1st               40.721651
# 2              3185           City Hall               40.717733
# 3              3185           City Hall               40.717733
# 4              3192  Liberty Light Rail               40.711242
#
#    start station longitude  end station id         end station name  \
# 0               -74.032108            3213           Van Vorst Park
# ...

# %%
Mar = pd.read_csv(mar)

# %%
Mar[['startdate', 'starttime']] = Mar.starttime.str.split(expand=True)

# %%
Mar[['stopdate', 'stoptime']] = Mar.stoptime.str.split(expand=True)

# %%
Mar = Mar[['tripduration','startdate','starttime','stopdate','stoptime','start station id','start station name','start station latitude','start station longitude','end station id','end station name','end station latitude','end station longitude','bikeid','usertype','birth year','gender']]

# %%
Mar.head()
# Out:
#    tripduration   startdate      starttime    stopdate       stoptime  \
# 0           389  2020-03-01  00:14:07.0000  2020-03-01  00:20:36.0880
# 1           242  2020-03-01  00:48:06.4390  2020-03-01  00:52:08.9870
# 2           124  2020-03-01  01:08:46.4880  2020-03-01  01:10:51.2780
# 3           104  2020-03-01  01:22:35.4790  2020-03-01  01:24:20.2470
# 4           228  2020-03-01  01:39:20.2680  2020-03-01  01:43:09.1380
#
#    start station id start station name  start station latitude  \
# 0              3202       Newport PATH               40.727224
# 1              3185          City Hall               40.717733
# 2              3272       Jersey & 3rd               40.723332
# 3              3202       Newport PATH               40.727224
# 4              3194    McGinley Square               40.725340
#
#    start station longitude  end station id   end station name  \
# 0               -74.033759            3203      Hamilton Park
# ...

# %%
Apr = pd.read_csv(apr)

# %%
Apr[['startdate', 'starttime']] = Apr.starttime.str.split(expand=True)

# %%
Apr[['stopdate', 'stoptime']] = Apr.stoptime.str.split(expand=True)

# %%
Apr = Apr[['tripduration','startdate','starttime','stopdate','stoptime','start station id','start station name','start station latitude','start station longitude','end station id','end station name','end station latitude','end station longitude','bikeid','usertype','birth year','gender']]

# %%
Apr.head()
# Out:
#    tripduration   startdate      starttime    stopdate       stoptime  \
# 0          1437  2020-04-01  01:06:20.6300  2020-04-01  01:30:17.9680
# 1           264  2020-04-01  05:02:42.0570  2020-04-01  05:07:06.1260
# 2           254  2020-04-01  06:20:28.1190  2020-04-01  06:24:42.1380
# 3           429  2020-04-01  06:33:30.5170  2020-04-01  06:40:40.1990
# 4           805  2020-04-01  06:38:32.9220  2020-04-01  06:51:58.2050
#
#    start station id start station name  start station latitude  \
# 0              3678      Fairmount Ave               40.725726
# 1              3207        Oakland Ave               40.737604
# 2              3678      Fairmount Ave               40.725726
# 3              3195            Sip Ave               40.730897
# 4              3193       Lincoln Park               40.724605
#
#    start station longitude  end station id end station name  \
# 0               -74.071959            3678    Fairmount Ave
# ...

# %%
May = pd.read_csv(may)

# %%
May[['startdate', 'starttime']] = May.starttime.str.split(expand=True)

# %%
May[['stopdate', 'stoptime']] = May.stoptime.str.split(expand=True)

# %%
May = May[['tripduration','startdate','starttime','stopdate','stoptime','start station id','start station name','start station latitude','start station longitude','end station id','end station name','end station latitude','end station longitude','bikeid','usertype','birth year','gender']]

# %%
May.head()
# Out:
#    tripduration   startdate      starttime    stopdate       stoptime  \
# 0           349  2020-05-01  00:09:45.5860  2020-05-01  00:15:35.2930
# 1           138  2020-05-01  01:11:22.5280  2020-05-01  01:13:41.2460
# 2           229  2020-05-01  05:31:29.5350  2020-05-01  05:35:19.2400
# 3           261  2020-05-01  05:51:39.3960  2020-05-01  05:56:00.9370
# 4           168  2020-05-01  06:06:31.9510  2020-05-01  06:09:20.1410
#
#    start station id          start station name  start station latitude  \
# 0              3195                     Sip Ave               40.730897
# 1              3792  Columbus Dr at Exchange Pl               40.716870
# 2              3483               Montgomery St               40.719420
# 3              3278            Monmouth and 6th               40.725685
# 4              3194             McGinley Square               40.725340
#
#    start station longitude  end station id end station name  \
# ...

# %%
Jun = pd.read_csv(jun)

# %%
Jun[['startdate', 'starttime']] = Jun.starttime.str.split(expand=True)

# %%
Jun[['stopdate', 'stoptime']] = Jun.stoptime.str.split(expand=True)

# %%
Jun = Jun[['tripduration','startdate','starttime','stopdate','stoptime','start station id','start station name','start station latitude','start station longitude','end station id','end station name','end station latitude','end station longitude','bikeid','usertype','birth year','gender']]

# %%
Half2020 = Jan.append([Feb, Mar, Apr, May, Jun], ignore_index=True)

# %%
Half2020
# Out:
#         tripduration   startdate      starttime    stopdate       stoptime  \
# 0                226  2020-01-01  00:04:50.1920  2020-01-01  00:08:37.0370
# 1                377  2020-01-01  00:16:01.6700  2020-01-01  00:22:19.0800
# 2                288  2020-01-01  00:17:33.8770  2020-01-01  00:22:22.4420
# 3                435  2020-01-01  00:32:05.9020  2020-01-01  00:39:21.0660
# 4                231  2020-01-01  00:46:19.6780  2020-01-01  00:50:11.3440
# ...              ...         ...            ...         ...            ...
# 137962          2828  2020-06-30  23:53:19.7380  2020-07-01  00:40:28.5760
# 137963          2729  2020-06-30  23:54:44.0100  2020-07-01  00:40:13.6470
# 137964          2788  2020-06-30  23:54:52.1920  2020-07-01  00:41:20.6500
# 137965          2702  2020-06-30  23:56:14.6650  2020-07-01  00:41:16.7820
# 137966          2649  2020-06-30  23:57:46.1490  2020-07-01  00:41:55.5060
#
# ...

# %%
Half2020.to_csv("Jan-Jun-Citibike-tripdata-2020.csv", index=False)
